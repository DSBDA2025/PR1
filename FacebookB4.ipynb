# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/Omkar/Downloads/dataset_Facebook.csv',delimiter=';')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
numeric_data = data.select_dtypes(include=['float64', 'int64'])

# %%
correlation_matrix = numeric_data.corr()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, cmap='YlGnBu', annot=True)
plt.title('Correlation Heatmap of Facebook Metrics')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=data, x='Post Month', y='Lifetime Post Total Reach', hue='Type', estimator='mean')
plt.title('Average Lifetime Post Total Reach by Post Month and Type')
plt.xlabel('Post Month')
plt.ylabel('Average Lifetime Post Total Reach')
plt.legend(title='Post Type')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=data, x='Lifetime Post Total Reach', hue='Type', multiple='stack', bins=30, kde=True)
plt.title('Distribution of Lifetime Post Total Reach by Post Type')
plt.xlabel('Lifetime Post Total Reach')
plt.ylabel('Frequency')
plt.legend(title='Post Type')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
temp_df = data[['Lifetime Post Total Reach', 'Lifetime Post Total Impressions', 
                 'Lifetime Engaged Users', 'Total Interactions', 'Page total likes', 'Type']]

# Create a pair plot
plt.figure(figsize=(15, 10))
sns.pairplot(temp_df, hue="Type")
plt.suptitle("Looking for Insights in Facebook Metrics Data", y=1.02)
plt.tight_layout()
plt.show()
